# %% [markdown]
# <a href="https://colab.research.google.com/github/25prateek/google_colab/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x=[4,7,8,9,11,]
y=[13,23,5,7,9,]
player=['virat','dhoni','vijay','dhawan']
runs=[120,44,77,33]
exp=[0.1,0,0,0.3] #explode use ke liye slide bhar nikalta h

# %%
#@title graph
plt.xlabel('x=axis') 
plt.ylabel('y=axis')
plt.plot(x,y)
plt.grid(color='green')
plt.legend()
plt.show()
plt.bar(x,y)
plt.show()
plt.grid(color='royalblue')
plt.scatter(x,y)# show point at that poin
# Out:
# No handles with labels found to put in legend.

# %%
#plt.xlabel('x=axis')
#plt.ylabel('y=axis')
plt.pie(runs,labels=player,explode=exp,shadow=True,autopct = "%1.1f%%")
plt.grid(runs,color='green')
plt.legend()
plt.show()
#plt.bar(x,y)
